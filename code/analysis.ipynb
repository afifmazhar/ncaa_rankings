# %%
import pandas as pd
import sklearn as sk
import os
import numpy as np
from sklearn import linear_model
from sklearn.linear_model import LinearRegression

# %%
game_results = pd.read_csv("../data/clean/game_results_clean.csv", encoding="ISO-8859-1")
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3326, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-68-7fa64496e257>", line 1, in <module>
#     game_results = pd.read_csv("../data/clean/game_results_clean.csv", encoding="ISO-8859-1")
#   File "/opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py", line 685, in parser_f
#     return _read(filepath_or_buffer, kwds)
#   File "/opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py", line 457, in _read
#     parser = TextFileReader(fp_or_buf, **kwds)
#   File "/opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py", line 895, in __init__
#     self._make_engine(self.engine)
#   File "/opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py", line 1135, in _make_engine
#     self._engine = CParserWrapper(self.f, **self.options)
#   File "/opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py", line 1917, in __init__
#     self._reader = parsers.TextReader(src, **kwds)
#   File "pandas/_libs/parsers.pyx", line 382, in pandas._libs.parsers.TextReader.__cinit__
#   File "pandas/_libs/parsers.pyx", line 689, in pandas._libs.parsers.TextReader._setup_parser_source
# FileNotFoundError: [Errno 2] File b'../data/clean/game_results_clean.csv' does not exist: b'../data/clean/game_results_clean.csv'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2040, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'FileNotFoundError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/opt/anaconda3/lib/python3.7/site-packages/IPython/core/ultratb.py", line 319, in wrapped
#     return f(*args, **kwargs)
#   File "/opt/anaconda3/lib/python3.7/site-packages/IPython/core/ultratb.py", line 353, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/opt/anaconda3/lib/python3.7/inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/opt/anaconda3/lib/python3.7/inspect.py", line 1460, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/opt/anaconda3/lib/python3.7/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/opt/anaconda3/lib/python3.7/inspect.py", line 725, in getmodule
#     file = getabsfile(object, _filename)
#   File "/opt/anaconda3/lib/python3.7/inspect.py", line 709, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/opt/anaconda3/lib/python3.7/posixpath.py", line 383, in abspath
#     cwd = os.getcwd()
# FileNotFoundError: [Errno 2] No such file or directory
# ---------------------------------------------------------------------------

# %%
game_results.head()
mean_value=game_results['team2_rpi'].mean()
game_results['team2_rpi'].fillna(value=game_results['team2_rpi'].mean(), inplace=True)

# %%
game_results['team2_rpi'].isnull().sum()
# Out:
# 0

# %%
x = game_results[['team1_osrs','team1_dsrs','team1_rpi','team2_osrs','team2_dsrs','team2_rpi']]
y = game_results['score_diff']

# %%
regr = LinearRegression(fit_intercept=False).fit(x,y)
print('Intercept: \n', regr.intercept_)
print('Coefficients: \n', regr.coef_)
# Out:
# Intercept:
#  0.0
# Coefficients:
#  [  1.02808354   1.11286337 -30.53191958  -0.96870805  -1.07654445
#   29.23121343]

# %%
game_results.head()
# Out:
#    year                  round           team1       team2  score1  score2  \
# 0  2019  National Championship        Virginia  Texas Tech      85      77
# 1  2019             Final Four  Michigan State  Texas Tech      51      61
# 2  2019             Final Four        Virginia      Auburn      63      62
# 3  2019            Elite Eight        Virginia      Purdue      80      75
# 4  2019            Elite Eight         Gonzaga  Texas Tech      69      75
#
#    score_diff  seed1  seed2  seed_diff  ...  team1_dsrs  team1_srs  team1_rpi  \
# 0           8      1      3         -2  ...       20.38      25.46     0.6554
# 1         -10      2      3         -1  ...       11.99      24.93     0.6468
# 2           1      1      4         -3  ...       20.38      25.46     0.6554
# 3           5      1      3         -2  ...       20.38      25.46     0.6554
# 4          -6      1      3         -2  ...        9.22      27.79     0.6443
#
#    team2_sos  team2_osrs  team2_dsrs  team2_srs  team2_rpi  team1_rating  \
# 0       9.53        5.95       16.84      22.79     0.6187      7.892200
# 1       9.53        5.95       16.84      22.79     0.6187      6.898587
# 2      10.92       13.12        7.72      20.84     0.6187      7.892200
# 3      11.99       12.29        9.11      21.40     0.6199      7.892200
# 4       9.53        5.95       16.84      22.79     0.6187      9.680396
#
#    team2_rating
# 0     -5.807470
# 1     -5.807470
# 2     -2.935021
# 3     -3.592313
# 4     -5.807470
#
# [5 rows x 22 columns]

# %%
game_results['team1_rating'] = (game_results['team1_osrs']*1.02808354)+(game_results['team1_dsrs']*1.11286337)+(game_results['team1_rpi']*-30.53191958)
game_results['team2_rating'] = (game_results['team2_osrs']*-0.96870805)+(game_results['team2_dsrs']*-1.07654445)+(game_results['team2_rpi']*29.23121343)

# %%
game_results.head()
# Out:
#    year                  round           team1       team2  score1  score2  \
# 0  2019  National Championship        Virginia  Texas Tech      85      77
# 1  2019             Final Four  Michigan State  Texas Tech      51      61
# 2  2019             Final Four        Virginia      Auburn      63      62
# 3  2019            Elite Eight        Virginia      Purdue      80      75
# 4  2019            Elite Eight         Gonzaga  Texas Tech      69      75
#
#    score_diff  seed1  seed2  seed_diff  ...  team1_dsrs  team1_srs  team1_rpi  \
# 0           8      1      3         -2  ...       20.38      25.46     0.6554
# 1         -10      2      3         -1  ...       11.99      24.93     0.6468
# 2           1      1      4         -3  ...       20.38      25.46     0.6554
# 3           5      1      3         -2  ...       20.38      25.46     0.6554
# 4          -6      1      3         -2  ...        9.22      27.79     0.6443
#
#    team2_sos  team2_osrs  team2_dsrs  team2_srs  team2_rpi  team1_rating  \
# 0       9.53        5.95       16.84      22.79     0.6187      7.892200
# 1       9.53        5.95       16.84      22.79     0.6187      6.898587
# 2      10.92       13.12        7.72      20.84     0.6187      7.892200
# 3      11.99       12.29        9.11      21.40     0.6199      7.892200
# 4       9.53        5.95       16.84      22.79     0.6187      9.680396
#
#    team2_rating
# 0     -5.807470
# 1     -5.807470
# 2     -2.935021
# 3     -3.592313
# 4     -5.807470
#
# [5 rows x 22 columns]

# %%
game_results.to_csv(os.path.join("..","data", "clean", "game_results_clean.csv"), index = False)
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3326, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-66-6fc166775e81>", line 1, in <module>
#     game_results.to_csv(os.path.join("..","data", "clean", "game_results_clean.csv"), index = False)
#   File "/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py", line 3228, in to_csv
#     formatter.save()
#   File "/opt/anaconda3/lib/python3.7/site-packages/pandas/io/formats/csvs.py", line 183, in save
#     compression=self.compression,
#   File "/opt/anaconda3/lib/python3.7/site-packages/pandas/io/common.py", line 399, in _get_handle
#     f = open(path_or_buf, mode, encoding=encoding, newline="")
# FileNotFoundError: [Errno 2] No such file or directory: '../data/clean/game_results_clean.csv'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2040, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'FileNotFoundError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/opt/anaconda3/lib/python3.7/site-packages/IPython/core/ultratb.py", line 319, in wrapped
#     return f(*args, **kwargs)
#   File "/opt/anaconda3/lib/python3.7/site-packages/IPython/core/ultratb.py", line 353, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/opt/anaconda3/lib/python3.7/inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/opt/anaconda3/lib/python3.7/inspect.py", line 1460, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/opt/anaconda3/lib/python3.7/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/opt/anaconda3/lib/python3.7/inspect.py", line 725, in getmodule
#     file = getabsfile(object, _filename)
#   File "/opt/anaconda3/lib/python3.7/inspect.py", line 709, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/opt/anaconda3/lib/python3.7/posixpath.py", line 383, in abspath
#     cwd = os.getcwd()
# FileNotFoundError: [Errno 2] No such file or directory
# ---------------------------------------------------------------------------
